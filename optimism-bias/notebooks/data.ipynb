# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('../data/run_1.csv')

# %% [raw]
# data[data.run==1]

# %% [raw]
# data=data[data.run==0]

# %%
plt.hist(data[data.run==1].casino)
# Out:
# (array([24.,  0.,  0., 24.,  0.,  0., 24.,  0.,  0., 24.]),
#  array([1. , 1.3, 1.6, 1.9, 2.2, 2.5, 2.8, 3.1, 3.4, 3.7, 4. ]),
#  <BarContainer object of 10 artists>)

# %%
for machine in range(2,3):
    plt.plot(data[data.casino==machine].trial, data[data.casino==machine].choice)
    #plt.hist([data[data.machine==machine].choice for machine in range(1,5)])
    plt.legend(str(machine))

# %%
plt.hist([data[data.casino==machine].choice for machine in range(1,5)]);#, density=True);
